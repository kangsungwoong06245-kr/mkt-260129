# %%
price = "100 달러"
exchange_rate = 1480
#price 라는 변수에 있는 100달러의 값을 환율을 적용해서 한화(한국 돈)으로 변화해서 값을 출력해주세요

# 문자열 : 인덱스 -> 슬라이싱
print(type(int(price[0:3])))
print(result)
print(f"{result :,}원")
# Out:
# <class 'int'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 7
#       3 #price 라는 변수에 있는 100달러의 값을 환율을 적용해서 한화(한국 돈)으로 변화해서 값을 출력해주세요
#       4
#       5 # 문자열 : 인덱스 -> 슬라이싱
#       6 print(type(int(price[0:3])))
# ----> 7 print(result)
#       8 print(f"{result :,}원")
#
# NameError: name 'result' is not defined

# %%
# 반복문을 활용해서 구구단 2~9단까지 아래에 출력해주세요!

# 2~9 반복

for index_1in range(2, 10) :
    print(f"==== 구구단 {index_1} 단 ====")
    for index_2 in range(1, 10) :
        print(f"{index_1} x {index_2} = {index_1} * {index_2}")
    print("\n")
# Out:
#   Cell In[45], line 5
#     for index_1in range(2, 10) :
#                   ^
# SyntaxError: invalid syntax
