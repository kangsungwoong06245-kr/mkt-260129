# %% [markdown]
# #request 문법
# - select = (선택자를 기준) 복수의 값을 찾아올떄 사용, 유사리스트 형태로 값을 반환(반복문 사용가능)
# - select_one = 단수의 값을 찾아올떄
# - text = 크롤링해온 값에서 문자만 남기고 싶을 때 사용
# - strip = 해당 문자 앞,쉬 빈여백 혹은 이스케이프 사퀀스 제거하고자 할 때 사용
# - .
# - #
# - ["속셩명"] : ["data-price"]
# - get_text("", strip=True)
# - find : (태그를 기준) 단수의 값을 찾아올 때,
# - find_all : (태그를 기준) 복수의 값을 찾아올 때

# %%
import requests
from bs4 import BeautifulSoup

url ="https://crawlingtest-260122.netlify.app"

headers= {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
response.encoding = "utf-8"

soup = BeautifulSoup(response.text, "html.parser")

#상품명은 여러개 존재
#상품명은 특정한 이름 가지고 있음  product_name
#한번에 세개 가능=한개의 변수안에 3개의 값을 포함
#list의 형태로 가지고와야됨
price = [tag.text.strip() for tag in soup.select(".price")] 
print(price)
#strip은 오직 문자열 객체에서만 가능
#[for in]
# Out:
# ['89,000원', '129,000원', '45,000원']

# %%
import requests
from bs4 import BeautifulSoup

url ="https://crawlingtest-260122.netlify.app"

headers= {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
response.encoding = "utf-8"

soup = BeautifulSoup(response.text, "html.parser")

#상품명은 여러개 존재
#상품명은 특정한 이름 가지고 있음  product_name
#한번에 세개 가능=한개의 변수안에 3개의 값을 포함
#list의 형태로 가지고와야됨
# names = [tag.text.strip() for tag in soup.select(".product-name, .category")] 
#for card in soup.select(".product-card") :
 #   name = card.select_one(".product-name").text.strip()
  #  category = card.select_one(".category").text.strip()
   # print(f"{name} / {category}")
#strip은 오직 문자열 객체에서만 가능
#[for in]

#상품당 가격
for card in soup.select(".product-card") :
    name = card.select_one(".product-name").text.strip()
    price = int(card.select_one(".price")["data-price"])
    print(type(price))
    print(f"{name} / {price:,}")

    #
# Out:
# <class 'int'>
# 오프화이트 반팔 티셔츠 / 89,000
# <class 'int'>
# 나이키 러닝화 / 129,000
# <class 'int'>
# 가죽 카드 지갑 / 45,000

# %%
product_names = [tag.get_text(strip=True) for tag in soup.select("h2.product-name")]

print(product_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 product_names = [tag.get_text(strip=True) for tag in soup.select("h2.product-name")]
#       3 print(product_names)
#
# NameError: name 'soup' is not defined

# %%
#뉴하고 힛 벳지가 있는 상품만 상품명을 크롤링해오기
import requests
from bs4 import BeautifulSoup

url ="https://crawlingtest-260122.netlify.app"

headers= {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
response.encoding = "utf-8"

soup = BeautifulSoup(response.text, "html.parser")

#상품명은 여러개 존재
#상품명은 특정한 이름 가지고 있음  product_name
#한번에 세개 가능=한개의 변수안에 3개의 값을 포함
#list의 형태로 가지고와야됨
# names = [tag.text.strip() for tag in soup.select(".product-name, .category")] 
#for card in soup.select(".product-card") :
 #   name = card.select_one(".product-name").text.strip()
  #  category = card.select_one(".category").text.strip()
   # print(f"{name} / {category}")
#strip은 오직 문자열 객체에서만 가능
#[for in]

#상품당 가격
#for card in soup.select(".product-card") :
 #   name = card.select_one(".badge new, .badge hot").text.strip()
  #  price = card.select_one(".product-name")
   # print(f"{name} / {price:,}")
for card in soup.select(".product-card") :
    badge = card.select_one(".badge")
    if badge : 
        name = card.select_one(".product-name").text.strip()
        print(f"{name} / {badge.text.strip()}")
# Out:
# 오프화이트 반팔 티셔츠 / NEW
# 나이키 러닝화 / HOT

# %%
#뉴하고 힛 벳지가 있는 상품만 상품명을 크롤링해오기
import requests
from bs4 import BeautifulSoup

url ="https://crawlingtest-260122.netlify.app"

headers= {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
response.encoding = "utf-8"

soup = BeautifulSoup(response.text, "html.parser")

#상품명은 여러개 존재
#상품명은 특정한 이름 가지고 있음  product_name
#한번에 세개 가능=한개의 변수안에 3개의 값을 포함
#list의 형태로 가지고와야됨
# names = [tag.text.strip() for tag in soup.select(".product-name, .category")] 
#for card in soup.select(".product-card") :
 #   name = card.select_one(".product-name").text.strip()
  #  category = card.select_one(".category").text.strip()
   # print(f"{name} / {category}")
#strip은 오직 문자열 객체에서만 가능
#[for in]

#상품당 가격
#for card in soup.select(".product-card") :
 #   name = card.select_one(".badge new, .badge hot").text.strip()
  #  price = card.select_one(".product-name")
   # print(f"{name} / {price:,}")
#5만원 이상의 상품만 크롤링

for card in soup.select(".product-card") :
    price = int(card.select_one(".price")["data-price"])
    if price >=50000 :
        name = card.select_one(".product-name").text.strip()
        print(f"{price:,} / {name}")
    
# 특정 사이트에 접속 데이터 수집 + 재활용 (프로토타입)
# Out:
# 89,000 / 오프화이트 반팔 티셔츠
# 129,000 / 나이키 러닝화

# %%
# 특정 사이트에 접속 데이터 수집 + 재활용 (프로토타입)
# 수집한 상품별 상품명, 카테고리, 가격을 하나의 딕셔너리로 만들어주시고, 해당 딕셔너리가 하나의 리스 안에 저장될 수 있도록 해주셍
# [ {"name" : "...." ,"category" : "...." "price" : "...."} 0
import requests
from bs4 import BeautifulSoup

url ="https://crawlingtest-260122.netlify.app"

headers= {
        "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36"
}
response = requests.get(url, headers=headers)
response.encoding = "utf-8"

soup = BeautifulSoup(response.text, "html.parser")

items = []

for card in soup.select(".product-card") :
    items.append({"name" : card.select_one(".product-name").text.strip(),
                  "category" : card.select_one(".category").text.strip(),
                  "price" : int(card.select_one(".price")["data-price"])
                  
        
    })
print(items)
# Out:
# [{'name': '오프화이트 반팔 티셔츠', 'category': '의류', 'price': 89000}, {'name': '나이키 러닝화', 'category': '신발', 'price': 129000}, {'name': '가죽 카드 지갑', 'category': '잡화', 'price': 45000}]

# %%
from bs4 import BeautifulSoup

html = """
<p class="desc">
    여름용
    <strong>오프화이트</strong>
    반팔 티셔츠
</p>
"""

soup =BeautifulSoup(html, "html.parser")
# desc = soup.select_one(".desc").text.strip() 앞.뒤쪽 영역의 빈 공백
desc = soup.select_one(".desc").get_text(" ", strip=True) # 내부 영역의 빈 공배까지도 영향
print(desc)
# Out:
# 여름용 오프화이트 반팔 티셔츠

# %%
from bs4 import BeautifulSoup

html = """
<div class="product-card">
      <h2 class="product-name">나이키 런닝화</h2>
      <p class="cateogry">신발</p>
      <p class="price" data-price="129000">129.000원</p>
</div>
"""

soup = BeautifulSoup(response.text, "html.parser")

# for tag in soup.select(".product-name") :
# print(tag.text.strip()) #strip() :문자열 객체

card = soup.find("div", class_="product-card")
name = card.fing("h2",class_="product-name").text.strip() 
price = card. find("p", class_="price")["data-price"] #select_one은 문서 위쪽부터 스캔하다가 매칭되는 순간 스캔 멈춤
print(price)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[110], line 17
#      13 # for tag in soup.select(".product-name") :
#      14 # print(tag.text.strip()) #strip() :문자열 객체
#      16 card = soup.find("div", class_="product-card")
# ---> 17 name = card.fing("h2",class_="product-name").text.strip()
#      18 price = card. find("p", class_="price")["data-price"] #select_one은 문서 위쪽부터 스캔하다가 매칭되는 순간 스캔 멈춤
#      19 print(price)
#
# TypeError: 'NoneType' object is not callable

# %%
from bs4 import BeautifulSoup

html= """ 
<body id="body">
    <p class="cssstyle">오늘의 추천 상품입니다.</p>
    <p class="cssstyle">지금 구매하면 할인!</p>
    <p align="center">이 문구는 중앙정렬 안내입니다.</p>
    <div class="product-card">
        <h2 class="product-name">나이키 런닝화</h2>
        <p class="cateogry">신발</p>
        <p class="price" data-price="129000">129.000원</p>
     </div>
</body>
"""

soup = BeautifulSoup(html, "html.parser")

#data = soup.find("p", "cssstyle") #class_ 생략
#print(data.get_text(" ", strip=True))

#data = soup.find("p", attrs={"align" : "center"})
data = soup.find(id="body")
print(data.get_text(" ", strip=True))



#datas = soup.find_all("p", class_="cssstyle")
#for data in datas :
#    print(data.get_text(" ", strip=True))

# 1) select & select_one
# 2) find & find_all (*일반적인 사이트는 대부분 div 남발)
# Out:
# 이 문구는 중앙정렬 안내입니다.
