# %% [markdown]
# # 해쉬 주석 코드가 실행되는 공간 단위 셀 *에스테릭 작동중인지 여부 확인
# #셀에 숫자가 나온건 작동완료
# # kernel 커널 가상환경 라이브러리 모듈

# %% [markdown]
# ### 파이썬 기초문법
# - 객체지향

# %% [markdown]
# # 네이버 웨보털 뉴스 카테고리 키워드 크롤링
# - 크롤링 crowling 외부에서 데이터 수집 행위

# %%
import requests 
from bs4 import BeautifulSoup

query = "마케팅" # 변수 선언 후 깂을 할당 
url = f"https://search.naver.com/search.naver?where=news&ie=utf8&sm=nws_hty&query=(query)" # F-string  문법 

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/143.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser" )

titles = soup.select( "a.fender-ui_228e3bd1.MNH2zYqVX0VCatL92VdS" )

for title in enumerate(titles) : 
    print(f"{i}. {title.text}")


# bs4.BeautifulSoup()

# print(response) # print 함수 기능 구현
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 17
#      14 titles = soup.select( "a.fender-ui_228e3bd1.MNH2zYqVX0VCatL92VdS" )
#      16 for title in enumerate(titles) :
# ---> 17     print(f"{i}. {title.text}")
#
# NameError: name 'i' is not defined
